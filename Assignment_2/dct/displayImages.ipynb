# %%
from PIL import Image
im = Image.open('opencv_dct.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0xB3FCCB20>

# %%
from PIL import Image
im = Image.open('dct_lab_naive.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0xB0994328>

# %%
from PIL import Image
im = Image.open('dct_lab_opt.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0xB5035EB0>

# %%
from PIL import Image
im = Image.open('original_color.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=640x480 at 0xB3F88A00>

# %%
from PIL import Image
im = Image.open('resized_grayscale.tif')
im
# Out:
# <PIL.TiffImagePlugin.TiffImageFile image mode=L size=64x64 at 0xB3F817C0>
